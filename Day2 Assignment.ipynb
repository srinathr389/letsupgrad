# %% [markdown]
# List in built in functions

# %%
#Lists
#example-1 using .insert
lst=[99,88,77,"hii",1.1,['p','y','t','h','o','n']]

# %%
lst
# Out:
# [99, 88, 77, 'hii', 1.1, ['p', 'y', 't', 'h', 'o', 'n']]

# %%
lst.insert(2,"day")

# %%
lst
# Out:
# [99, 88, 'day', 77, 'hii', 1.1, ['p', 'y', 't', 'h', 'o', 'n']]

# %%
# example-2 using .count

lst.count('hii')
# Out:
# 1

# %%
lst.append(99)

# %%
lst
# Out:
# [99, 88, 'day', 77, 'hii', 1.1, ['p', 'y', 't', 'h', 'o', 'n'], 0, 99]

# %% [markdown]
# example-3

# %%
# using above created list with different function using .count
lst
# Out:
# [99, 88, 'day', 77, 'hii', 1.1, ['p', 'y', 't', 'h', 'o', 'n'], 0, 99]

# %%
lst.count(99)
# Out:
# 2

# %%
lst
# Out:
# ['day', 77, 'hii', 1.1, ['p', 'y', 't', 'h', 'o', 'n'], 0]

# %% [markdown]
# Example-4
# using .pop

# %%
lst.pop(0)
# Out:
# 88

# %%
lst.pop(6)
# Out:
# 99

# %% [markdown]
# Example-5

# %%
#example-5 using .reverse
lst
# Out:
# ['day', 77, 'hii', 1.1, ['p', 'y', 't', 'h', 'o', 'n'], 0]

# %%
lst.reverse()

# %%
lst
# Out:
# [0, ['p', 'y', 't', 'h', 'o', 'n'], 1.1, 'hii', 77, 'day']

# %% [markdown]
#  Dict's In-Built Function

# %%
names ={"boy1":'ram',"boy2":'sam',"girl1":'sitha',"girl2":'latha'}

# %%
names
# Out:
# {'boy1': 'ram', 'boy2': 'sam', 'girl1': 'sitha', 'girl2': 'latha'}

# %%
#example-1
names.get("boy1")
# Out:
# 'ram'

# %%
#example-2
names.values()
# Out:
# dict_values(['ram', 'sam', 'sitha', 'latha'])

# %%
#example-3
names.items()
# Out:
# dict_items([('boy1', 'ram'), ('boy2', 'sam'), ('girl1', 'sitha'), ('girl2', 'latha')])

# %%
#example-4
names.keys()
# Out:
# dict_keys(['boy1', 'boy2', 'girl1', 'girl2'])

# %%
#examples-5
names.update()

# %%
names
# Out:
# {'boy1': 'ram', 'boy2': 'sam', 'girl1': 'sitha', 'girl2': 'latha'}

# %%
names1={"boy1":'jam'}

# %%
names.update(names1)

# %%
names
# Out:
# {'boy1': 'jam', 'boy2': 'sam', 'girl1': 'sitha', 'girl2': 'latha'}
